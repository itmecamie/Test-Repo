# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %%
# %reload_ext sql
# %sql sqlite:///my_data1.db

# %%
# %%sql
# DROP TABLE IF EXISTS SPACEXTABLE;
# CREATE TABLE SPACEXTABLE AS
# SELECT * FROM SPACEXTBL WHERE Date IS NOT NULL;
# Out:
#  * sqlite:///my_data1.db
# Done.
# Done.
# []

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
import sys
# !{sys.executable} -m pip install requests
import sqlite3
import pandas as pd

con = sqlite3.connect("my_data1.db")

# %pip install sqlalchemy==1.3.9
# %pip install -U ipython-sql sqlalchemy

# %config SqlMagic.style = 'PLAIN_COLUMNS'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached sqlalchemy-1.3.9-cp39-cp39-macosx_10_9_universal2.whl
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.45
#     Uninstalling SQLAlchemy-2.0.45:
#       Successfully uninstalled SQLAlchemy-2.0.45
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.9 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached sqlalchemy-2.0.45-py3-none-any.whl.metadata (9.5 kB)
# ...
# Using cached sqlalchemy-2.0.45-py3-none-any.whl (1.9 MB)
# ...
#   Attempting uninstall: sqlalchemy
# ...

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %pip install ipython-sql
# %pip install ipython-sql prettytable
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %reload_ext sql

# %%
import pandas as pd
import sqlite3

df = pd.read_csv(
    "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv"
)


with sqlite3.connect("my_data1.db") as con:
    df.to_sql("SPACEXTBL", con, if_exists="replace", index=False)

print("SPACEXTBL created successfully")
# Out:
# SPACEXTBL created successfully

# %%
# %pip install -q pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %reload_ext sql
# %sql sqlite:///my_data1.db
# %config SqlMagic.style = 'PLAIN_COLUMNS'

# %%
import pandas as pd

# Load SpaceX dataset (IBM / Coursera capstone)
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")

# Write to SQLite
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False, method="multi")

df.head()

import os
os.environ["DATABASE_URL"] = "sqlite:///my_data1.db"

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
pd.read_sql("""
DROP TABLE IF EXISTS SPACEXTABLE;
""", con)

pd.read_sql("""
CREATE TABLE SPACEXTABLE AS
SELECT *
FROM SPACEXTBL
WHERE Date IS NOT NULL;
""", con)

# Quick verify
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", con)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 pd.read_sql("""
#       2 DROP TABLE IF EXISTS SPACEXTABLE;
#       3 """, con)
#       5 pd.read_sql("""
#       6 CREATE TABLE SPACEXTABLE AS
#       7 SELECT *
#       8 FROM SPACEXTBL
#       9 WHERE Date IS NOT NULL;
#      10 """, con)
#      12 # Quick verify
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
# ...

# %%
pd.read_sql("""DROP TABLE IF EXISTS SPACEXTABLE;

CREATE TABLE SPACEXTABLE AS
SELECT *
FROM SPACEXTBL
WHERE Date IS NOT NULL;""", con)
# Out:
# ---------------------------------------------------------------------------
# Warning                                   Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# ...
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pd.read_sql("""DROP TABLE IF EXISTS SPACEXTABLE;
#       2
#       3 CREATE TABLE SPACEXTABLE AS
#       4 SELECT *
#       5 FROM SPACEXTBL
#       6 WHERE Date IS NOT NULL;""", con)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
# ...

# %% [markdown]
# ## Tasks (Fixed)
#
# Run each query cell below. These queries match the Coursera / IBM SpaceX SQL lab tasks and will output correctly from the `spacex` table.

# %% [markdown]
# ### Task 1
#
# **Display the names of the unique launch sites in the space mission.**

# %%
pd.read_sql("""SELECT DISTINCT Launch_Site
FROM SPACEXTABLE;""", con)
# Out:
#     Launch_Site
# 0   CCAFS LC-40
# 1   VAFB SLC-4E
# 2    KSC LC-39A
# 3  CCAFS SLC-40

# %% [markdown]
# ### Task 2
#
# **Display 5 records where launch sites begin with the string 'CCA'.**

# %%
pd.read_sql("""SELECT *
FROM spacex
WHERE "LaunchSite" LIKE 'CCA%'
LIMIT 5;""", con)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: spacex
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pd.read_sql("""SELECT *
#       2 FROM spacex
#       3 WHERE "LaunchSite" LIKE 'CCA%'
#       4 LIMIT 5;""", con)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# ...

# %% [markdown]
# ### Task 3
#
# **Display the total payload mass carried by boosters launched by NASA (CRS).**

# %%
# %%sql
# SELECT SUM("PayloadMass") AS Total_Payload_Mass
# FROM spacex
# WHERE "Customer" LIKE 'NASA (CRS)%';
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) no such table: spacex
# [SQL: SELECT SUM("PayloadMass") AS Total_Payload_Mass
# FROM spacex
# WHERE "Customer" LIKE 'NASA (CRS)%';]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Task 4
#
# **Display average payload mass carried by booster version F9 v1.1.**

# %%
# %%sql
# SELECT AVG("PayloadMass") AS Avg_Payload_Mass
# FROM spacex
# WHERE "BoosterVersion" = 'F9 v1.1';
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) no such table: spacex
# [SQL: SELECT AVG("PayloadMass") AS Avg_Payload_Mass
# FROM spacex
# WHERE "BoosterVersion" = 'F9 v1.1';]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Task 5
#
# **List the date when the first successful landing outcome in ground pad was achieved.**
#
# *(Hint: use MIN)*

# %%
# %%sql
# SELECT MIN("Date") AS First_Successful_Ground_Landing
# FROM spacex
# WHERE "Landing_Outcome" = 'True RTLS';
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) no such table: spacex
# [SQL: SELECT MIN("Date") AS First_Successful_Ground_Landing
# FROM spacex
# WHERE "Landing_Outcome" = 'True RTLS';]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Task 6
#
# **List the names of the boosters which have success in drone ship and have payload mass > 4000 and < 6000.**

# %%
# %%sql
# SELECT DISTINCT "BoosterVersion"
# FROM spacex
# WHERE "Landing_Outcome" = 'True ASDS'
#   AND "PayloadMass" > 4000
#   AND "PayloadMass" < 6000;
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) no such table: spacex
# [SQL: SELECT DISTINCT "BoosterVersion"
# FROM spacex
# WHERE "Landing_Outcome" = 'True ASDS'
#   AND "PayloadMass" > 4000
#   AND "PayloadMass" < 6000;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Task 7
#
# **List the total number of successful and failure mission outcomes.**

# %%
# %%sql
# SELECT "Mission_Outcome" AS Mission_Result,
#        COUNT(*) AS Total_Missions
# FROM spacex
# GROUP BY "Mission_Outcome";

# %% [markdown]
# ### Task 8
#
# **List all booster_versions that have carried the maximum payload mass (use a subquery).**

# %%
# %%sql
# SELECT DISTINCT "BoosterVersion"
# FROM spacex
# WHERE "PayloadMass" = (
#     SELECT MAX("PayloadMass")
#     FROM spacex
# );

# %% [markdown]
# ### Task 9
#
# **List the records which will display the month, failure landing outcomes in drone ship, booster versions, and launch site for the months in year 2015.**
#
# *Note: SQLite does not support month names, so use `substr(Date, 6, 2)` for the month and `substr(Date, 0, 5)='2015'` for year.*

# %%
# %%sql
# SELECT
#     substr("Date", 6, 2) AS Month,
#     "Landing_Outcome",
#     "BoosterVersion",
#     "LaunchSite"
# FROM spacex
# WHERE substr("Date", 0, 5) = '2015'
#   AND "Landing_Outcome" = 'False ASDS';

# %% [markdown]
# ### Task 10
#
# **Rank the count of landing outcomes between 2010-06-04 and 2017-03-20 in descending order.**

# %%
# %%sql
# SELECT
#     "Landing_Outcome",
#     COUNT(*) AS Outcome_Count
# FROM spacex
# WHERE "Date" BETWEEN '2010-06-04' AND '2017-03-20'
# GROUP BY "Landing_Outcome"
# ORDER BY Outcome_Count DESC;
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) no such table: spacex
# [SQL: SELECT
#     "Landing_Outcome",
#     COUNT(*) AS Outcome_Count
# FROM spacex
# WHERE "Date" BETWEEN '2010-06-04' AND '2017-03-20'
# GROUP BY "Landing_Outcome"
# ORDER BY Outcome_Count DESC;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## SQL Tasks (Corrected & Verified)

# %% [markdown]
# ### Display the names of the unique launch sites in the space mission.

# %%
# %%sql
# SELECT DISTINCT LaunchSite FROM SPACEXTABLE;

# %% [markdown]
# ### Display 5 records where launch sites begin with the string 'CCA'.

# %%
# %%sql
# SELECT * FROM SPACEXTABLE WHERE LaunchSite LIKE 'CCA%' LIMIT 5;

# %% [markdown]
# ### Display the total payload mass carried by boosters launched by NASA (CRS).

# %%
# %%sql
# SELECT SUM(PayloadMass) AS Total_Payload_Mass FROM SPACEXTABLE WHERE Customer LIKE 'NASA (CRS)%';

# %% [markdown]
# ### Display average payload mass carried by booster version F9 v1.1.

# %%
# %%sql
# SELECT AVG(PayloadMass) AS Avg_Payload_Mass FROM SPACEXTABLE WHERE BoosterVersion='F9 v1.1';

# %% [markdown]
# ### List the date when the first successful landing outcome in ground pad was achieved.

# %%
# %%sql
# SELECT MIN(Date) AS First_Successful_Ground_Landing FROM SPACEXTABLE WHERE Landing_Outcome='True RTLS';

# %% [markdown]
# ### List the names of the boosters which have success in drone ship and payload mass between 4000 and 6000.

# %%
# %%sql
# SELECT DISTINCT BoosterVersion FROM SPACEXTABLE WHERE Landing_Outcome='True ASDS' AND PayloadMass BETWEEN 4000 AND 6000;

# %% [markdown]
# ### List the total number of successful and failure mission outcomes.

# %%
# %%sql
# SELECT Mission_Outcome, COUNT(*) AS Total FROM SPACEXTABLE GROUP BY Mission_Outcome;

# %% [markdown]
# ### List all booster versions that have carried the maximum payload mass.

# %%
# %%sql
# SELECT DISTINCT BoosterVersion FROM SPACEXTABLE WHERE PayloadMass=(SELECT MAX(PayloadMass) FROM SPACEXTABLE);

# %% [markdown]
# ### List records for failure drone ship landings in 2015.

# %%
# %%sql
# SELECT substr(Date,6,2) AS Month, Landing_Outcome, BoosterVersion, LaunchSite FROM SPACEXTABLE WHERE substr(Date,1,4)='2015' AND Landing_Outcome='False ASDS';

# %% [markdown]
# ### Rank landing outcomes between 2010-06-04 and 2017-03-20.

# %%
# %%sql
# SELECT Landing_Outcome, COUNT(*) AS Outcome_Count FROM SPACEXTABLE WHERE Date BETWEEN '2010-06-04' AND '2017-03-20' GROUP BY Landing_Outcome ORDER BY Outcome_Count DESC;
